# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from stl_tools import numpy2stl

# %%
profile = np.loadtxt("ontario_lld.asc",skiprows=6)
profile = np.where(profile>-9999,profile,0)
profile = np.where(profile<0,profile,0)

# %%
profile_small = profile[::5,::5]

# %%
plt.imshow(profile_small);

# %%
numpy2stl(profile_small, "ontario_lld.stl", scale=0.15, solid=True)
